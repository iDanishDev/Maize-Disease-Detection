# %%
from PIL import Image
import os
import matplotlib.pyplot as plt

path1 = "data/Blight"

#img = Image.open(r'Corn_Blight (1).png')
#plt.imshow(img)
# Out:
# 'img' is not recognized as an internal or external command,
# operable program or batch file.
# 'plt.imshow' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array


testplant = cv2.imread('Corn_Blight (1).png')
test_img = cv2.resize(testplant, (128,128))

#plt.imshow(test_img)

test_img = img_to_array(test_img)/255
plt.imshow(test_img)
test_img = np.expand_dims(test_img, axis = 0)
